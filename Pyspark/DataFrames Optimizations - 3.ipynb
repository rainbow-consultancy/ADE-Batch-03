# %%
# Chache

# %%
df = spark.table("hive_metastore.rainbow.bucketed_table01")
display(df)

# %%
df = (
    df
    .withColumn()
    .withColumn()
)

# %%
df = (
    df.filter()
    .drop()
)

# %%
df.cache().first()

# %%
cache() --> memory_only

# %%
df.persist(StorageLevel.MEMORY_AND_DISK)
